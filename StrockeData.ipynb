# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data3=pd.read_csv("C:/Users/user/Downloads/healthcare-dataset-stroke-data.csv")
data3
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
data3.drop("id",axis = 1,inplace = True)

# %%
data3.drop(["ever_married","work_type","Residence_type"],axis = 1,inplace = True)

# %%
mean3=data3["bmi"].mean()

# %%
data3.fillna({"bmi":mean3},inplace=True)

# %%
data3.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
col = ["gender","smoking_status"]
le=LabelEncoder()
for i in col:
    data3[i]=le.fit_transform(data3[i])
data3
# Out:
#       gender   age  hypertension  heart_disease  avg_glucose_level        bmi  \
# 0          1  67.0             0              1             228.69  36.600000
# 1          0  61.0             0              0             202.21  28.893237
# 2          1  80.0             0              1             105.92  32.500000
# 3          0  49.0             0              0             171.23  34.400000
# 4          0  79.0             1              0             174.12  24.000000
# ...      ...   ...           ...            ...                ...        ...
# 5105       0  80.0             1              0              83.75  28.893237
# 5106       0  81.0             0              0             125.20  40.000000
# 5107       0  35.0             0              0              82.99  30.600000
# 5108       1  51.0             0              0             166.29  25.600000
# 5109       0  44.0             0              0              85.28  26.200000
#
#       smoking_status  stroke
# ...

# %%
data3.drop(["gender"],axis=1,inplace=True)

# %%
data3
# Out:
#        age  hypertension  heart_disease  avg_glucose_level        bmi  \
# 0     67.0             0              1             228.69  36.600000
# 1     61.0             0              0             202.21  28.893237
# 2     80.0             0              1             105.92  32.500000
# 3     49.0             0              0             171.23  34.400000
# 4     79.0             1              0             174.12  24.000000
# ...    ...           ...            ...                ...        ...
# 5105  80.0             1              0              83.75  28.893237
# 5106  81.0             0              0             125.20  40.000000
# 5107  35.0             0              0              82.99  30.600000
# 5108  51.0             0              0             166.29  25.600000
# 5109  44.0             0              0              85.28  26.200000
#
#       smoking_status  stroke
# 0                  1       1
# 1                  2       1
# 2                  2       1
# ...

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
var=MinMaxScaler()

# %%
numeric=data3.select_dtypes(include=["number"]).columns
data3[numeric]=var.fit_transform(data3[numeric])
data3
# Out:
#            age  hypertension  heart_disease  avg_glucose_level       bmi  \
# 0     0.816895           0.0            1.0           0.801265  0.301260
# 1     0.743652           0.0            0.0           0.679023  0.212981
# 2     0.975586           0.0            1.0           0.234512  0.254296
# 3     0.597168           0.0            0.0           0.536008  0.276060
# 4     0.963379           1.0            0.0           0.549349  0.156930
# ...        ...           ...            ...                ...       ...
# 5105  0.975586           1.0            0.0           0.132167  0.212981
# 5106  0.987793           0.0            0.0           0.323516  0.340206
# 5107  0.426270           0.0            0.0           0.128658  0.232532
# 5108  0.621582           0.0            0.0           0.513203  0.175258
# 5109  0.536133           0.0            0.0           0.139230  0.182131
#
#       smoking_status  stroke
# 0           0.333333     1.0
# 1           0.666667     1.0
# ...

# %%
var2=StandardScaler()

# %%
data3[numeric]=var2.fit_transform(data3[numeric])
data3
# Out:
#            age  hypertension  heart_disease  avg_glucose_level           bmi  \
# 0     1.051434     -0.328602       4.185032           2.706375  1.001234e+00
# 1     0.786070     -0.328602      -0.238947           2.121559  3.147952e-16
# 2     1.626390     -0.328602       4.185032          -0.005028  4.685773e-01
# 3     0.255342     -0.328602      -0.238947           1.437358  7.154182e-01
# 4     1.582163      3.043196      -0.238947           1.501184 -6.357112e-01
# ...        ...           ...            ...                ...           ...
# 5105  1.626390      3.043196      -0.238947          -0.494658  3.147952e-16
# 5106  1.670617     -0.328602      -0.238947           0.420775  1.442949e+00
# 5107 -0.363842     -0.328602      -0.238947          -0.511443  2.217363e-01
# 5108  0.343796     -0.328602      -0.238947           1.328257 -4.278451e-01
# 5109  0.034205     -0.328602      -0.238947          -0.460867 -3.498953e-01
#
#       smoking_status    stroke
# ...

# %%
import pandas as pd
data=pd.read_csv("///")
df=pf.DataFrame(data)
data.isnull().sum()
data.info
data.dropna(inplace=True)
mean=data["cl1"].mean()
mode=data["cl2"].mode[0]
#fill
data['ffg']=data['kiko'].replace(np.nan,mean)
data.fillna({'ffg':mean{},inplace=True)
d1=pd.read_csv(';lk')
d1.drop('ffg',axis=1,inplace=True)
cl=["q","a"]
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in cl:
    data[i]=le.fittransform(data[i])
    data

co=data.corr()
co
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(4.5
sns.heatmap(co,annot=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
data=pd.read_csv("C:/Users/user/Downloads/asiacup.csv")
data
# Out:
#           Team     Opponent Format      Ground  Year  Toss Selection  \
# 0     Pakistan    Sri Lanka    ODI     Sharjah  1984  Lose   Batting
# 1    Sri Lanka     Pakistan    ODI     Sharjah  1984   Win   Bowling
# 2        India    Sri Lanka    ODI     Sharjah  1984   Win   Bowling
# 3    Sri Lanka        India    ODI     Sharjah  1984  Lose   Batting
# 4        India     Pakistan    ODI     Sharjah  1984   Win   Batting
# ..         ...          ...    ...         ...   ...   ...       ...
# 249      India  Afghanistan   T20I  Dubai(DSC)  2022  Lose   Batting
# 250   Pakistan    Sri Lanka   T20I  Dubai(DSC)  2022  Lose   Batting
# 251  Sri Lanka     Pakistan   T20I  Dubai(DSC)  2022   Win   Bowling
# 252   Pakistan    Sri Lanka   T20I  Dubai(DSC)  2022   Win   Bowling
# 253  Sri Lanka     Pakistan   T20I  Dubai(DSC)  2022  Lose   Batting
#
#      Run Scored  Wicket Lost  Fours  Sixes  Extras  Run Rate  \
# 0         187.0          9.0    9.0    3.0    21.0      4.06
# ...

# %%
data.isnull().sum()
# Out:
# Team                         0
# Opponent                     0
# Format                       0
# Ground                       0
# Year                         0
# Toss                         0
# Selection                    0
# Run Scored                   2
# Wicket Lost                  2
# Fours                        2
# Sixes                        2
# Extras                       2
# Run Rate                     2
# Avg Bat Strike Rate          2
# Highest Score                2
# Wicket Taken                 2
# Given Extras                 2
# Highest Individual wicket    2
# Player Of The Match          2
# Result                       0
# dtype: int64

# %%
data.dropna(inplace=True)
data.isnull().sum()
# Out:
# Team                         0
# Opponent                     0
# Format                       0
# Ground                       0
# Year                         0
# Toss                         0
# Selection                    0
# Run Scored                   0
# Wicket Lost                  0
# Fours                        0
# Sixes                        0
# Extras                       0
# Run Rate                     0
# Avg Bat Strike Rate          0
# Highest Score                0
# Wicket Taken                 0
# Given Extras                 0
# Highest Individual wicket    0
# Player Of The Match          0
# Result                       0
# dtype: int64

# %%
Team=data.groupby("Team")["Format"].count()
Team
# Out:
# Team
# Afghanistan    14
# Bangladesh     50
# Hong Kong       8
# India          58
# Pakistan       54
# Sri Lanka      60
# UAE             8
# Name: Format, dtype: int64

# %%
cl=["blue","black","red","pink","gray","green","yellow"]
clr=cl[0:len(cl)]    
plt.bar(Team.index,Team.values,color=clr,label=Team.index)

plt.xticks(rotation=60)
plt.title("asf")
plt.xlabel("asd")
plt.ylabel("dad")
plt.show()

# %%
cl=[dsd]
clr=cl[0:len(clr)]
plt.bar(tea.index,team.value,color=clr)
plt.title="sdf"
